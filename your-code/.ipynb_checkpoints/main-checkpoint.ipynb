# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span><ul class="toc-item"><li><span><a href="#Uniform-Distribution" data-toc-modified-id="Uniform-Distribution-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Uniform Distribution</a></span></li><li><span><a href="#Normal-Distribution" data-toc-modified-id="Normal-Distribution-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Normal Distribution</a></span></li><li><span><a href="#Normal-Distribution-of-Real-Data" data-toc-modified-id="Normal-Distribution-of-Real-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Normal Distribution of Real Data</a></span></li><li><span><a href="#Exponential-Distribution" data-toc-modified-id="Exponential-Distribution-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Exponential Distribution</a></span></li><li><span><a href="#Exponential-Distribution-of-Real-Data" data-toc-modified-id="Exponential-Distribution-of-Real-Data-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Exponential Distribution of Real Data</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.28265999 2.58772326 2.56361568 2.32555271 2.53345917 2.34789786
#  2.86789982 2.19239729 2.03972142 2.60854038]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code hereimport numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform


#generamos la función que utiliza la función uniform.rvs() de scipy.stats para generar los números aleatorios distribuidos de manera uniforme.
def generar_distribucion_uniforme(bottom, ceiling, count):
    numeros_aleatorios = uniform.rvs(loc=bottom, scale=ceiling-bottom, size=count)
    return numeros_aleatorios

# Llamamos a la función dos veces con los parámetros especificados
datos1 = generar_distribucion_uniforme(10, 15, 100)
datos2 = generar_distribucion_uniforme(10, 60, 1000)

# plt.hist() de matplotlib.pyplot para generar los histogramas de las distribuciones uniformes generadas. 
#Especificamos el número de divisiones en los histogramas a través de bins=10.
plt.hist(datos1, bins=10, alpha=0.5, color='blue', label='Datos 1')
plt.hist(datos2, bins=10, alpha=0.5, color='green', label='Datos 2')
plt.xlabel('Valor')
plt.ylabel('Cantidad')
plt.title('Distribuciones Uniformes')
plt.legend()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
#La diferencia principal entre las dos distribuciones es en los valores que pueden tener los números generados y en la cantidad de números que se generan:

#En la primera distribución, los números generados estan en el rango del 10 al 15: se están generando solo 100 números, es posible que algunos valores aparezcan más veces que otros en el histograma.

#En la segunda distribución, los números generados pueden estar en un rango más amplio: desde 10 hasta 60. Al generar 1000 números, es más probable que cada valor tenga una cantidad similar de ocurrencias en el histograma.

#En resumen, la primera distribución genera menos números en un rango más pequeño, mientras que la segunda distribución genera más números en un rango más grande. Esto puede afectar cómo se ven los histogramas y las frecuencias de cada valor en ellos.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
import numpy as np
import matplotlib.pyplot as plt



#utiliza la función generar_distribucion_normal() para generar números aleatorios siguiendo una distribución normal

def generar_distribucion_normal(media, desviacion, cantidad):
    numeros_aleatorios = np.random.normal(media, desviacion, cantidad)
    return numeros_aleatorios

# Llamar a la función con los parámetros especificados:
datos1 = generar_distribucion_normal(10, 1, 1000)
#establecemos una media de 10 y una desviación estándar de 1. 
#esto significa que la mayoría de los números generados estarán cerca de 10 y estarán relativamente agrupados.

datos2 = generar_distribucion_normal(10, 50, 1000)
#la media sigue siendo 10, pero la desviación estándar se incrementa a 50; esto hace que los números generados 
#se dispersen más ampliamente alrededor de 10.


# Generar gráficos de las distribuciones normales: 
plt.hist(datos1, bins=30, alpha=0.5, color='blue', label='Datos 1')
plt.hist(datos2, bins=30, alpha=0.5, color='green', label='Datos 2')
#bins es un parámetro que se utiliza para controlar el número de divisiones o barras en el histograma. 
#En este caso, se le ha dado el valor de 30, lo que significa que el histograma tendrá 30 barras diferentes. 
#Cuanto mayor sea el número de barras, más detallada será la representación del histograma, pero también puede hacer que se 
#vea más "ruidoso".
#alpha es un parámetro que determina la transparencia de las barras del histograma. 
#Puede tener un valor entre 0 y 1. En este caso, se le ha dado el valor de 0.5, lo que significa que las barras serán 
#semitransparentes. Esto puede ayudar a que los diferentes histogramas superpuestos sean más distinguibles y visibles.
plt.xlabel('Valor')
plt.ylabel('Cantidad')
plt.title('Distribuciones Normales')
plt.legend()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
#como podemos ver al comparar ambas gráficas,los datos 2 (verdes) están mucho más dispersos, aunque en ambas sigue siendo la media

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("vehicles.csv")
# Obtener los valores de la variable "Fuel Barrels/Year"
fuel_barrels = data["Fuel Barrels/Year"]

# Crear histograma
plt.hist(fuel_barrels, bins=30, alpha=0.5, color='blue')
plt.xlabel("Fuel Barrels/Year") #X
plt.ylabel("Frequency") #Y
plt.title("Distribution of Fuel Barrels/Year")
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("vehicles.csv")

co2_emission = data["CO2 Emission Grams/Mile"]

# Crear histograma
plt.hist(co2_emission, bins=30, alpha=0.5, color='blue')
plt.xlabel("CO2 Emission Grams/Mile")
plt.ylabel("Frequency")
plt.title("Distribution of CO2 Emission Grams/Mile")
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Importar el archivo CSV
data = pd.read_csv("vehicles.csv")

# Obtener los valores de la variable "Combined MPG"
combined_mpg = data["Combined MPG"]

# Crear histograma
plt.hist(combined_mpg, bins=30, alpha=0.5, color='orange')
plt.xlabel("Combined MPG")
plt.ylabel("Frequency")
plt.title("Distribution of Combined MPG")
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
Combined MPG porque es lo más parecido a una campana con los datos mas o menos centrados a la media si lo comparamos con el resto.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
#numpy para generar números aleatorios y matplotlib.pyplot para crear gráficos.


def exponential_distribution(mean, size):
    data = np.random.exponential(scale=mean, size=size)
    return data
#función llamada exponential_distribution que toma dos argumentos: mean (media) y size (tamaño de la muestra). 
#Esta función generará una lista de números con una distribución exponencial utilizando np.random.exponential y los retornará.

#llamamos a la función exponential_distribution dos veces para generar dos secuencias de números:
sequence_1 = exponential_distribution(10, 10)
sequence_2 = exponential_distribution(10, 100)

# Crear histograma con 100 bins
plt.hist(sequence_1, bins=100, alpha=0.5, color='blue', label='Size 10')
plt.hist(sequence_2, bins=100, alpha=0.5, color='green', label='Size 100')

plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Distribución Exponencial")
plt.legend()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
La segunda secquencia es mucho más dispersa como vemos en el gráfico.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# Hint: This is same as saying P(x<15)
from scipy.stats import expon
#la librería scipy.stats que proporciona funciones estadísticas, incluida la distribución exponencial (expon).

def exponential_cdf(x, mean): #La función exponential_cdf(x, mean) toma dos argumentos: x es el valor para el cual 
    #se quiere calcular la probabilidad acumulativa, y mean es la media de la distribución exponencial.
    cdf = expon.cdf(x, scale=mean) #el parámetro scale que se establece como la media.
    return cdf

mean = 10  # Media de la distribución exponencial
x = 15  # Valor para el cual se calculará la probabilidad acumulativa

probability = exponential_cdf(x, mean)
print("La probabilidad de que el valor sea menor a", x, "es:", probability)
# Out:
# La probabilidad de que el valor sea menor a 15 es: 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
from scipy.stats import expon

def probabilidad_mas_de(x, media):
    probabilidad = 1 - expon.cdf(x, scale=media)
    return probabilidad

media = 10  # Media de la distribución exponencial
x = 15  # Valor para el cual se calculará la probabilidad acumulativa

probabilidad = probabilidad_mas_de(x, media)
print("La probabilidad de que un cliente pase más de", x, "minutos en el banco es:", probabilidad)
# Out:
# La probabilidad de que un cliente pase más de 15 minutos en el banco es: 0.2231301601484298
